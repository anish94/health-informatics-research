# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
illinois_emotion = pd.read_csv("Illinois_Emotion_State_Count.csv")

# %%
illinois_emotion.head()
# Out:
#   Week of:   Total Number of Posts  Fear  Anger  Joy  Sadness  Surprise  \
# 0  07/10/09                    148     7     27   12       10         0
# 1  07/17/09                    169     7     16   16        8         0
# 2  07/24/09                    179     7     33   12       10         0
# 3  07/31/09                    124     6     21   10        4         0
# 4  08/07/09                    125     4     17   17        4         0
#
#    Neutral  Disgust  No Emotion Attached
# 0       16       74                    2
# 1       19       98                    5
# 2       18       99                    0
# 3       14       68                    1
# 4       13       69                    1

# %%
# Summary of the dataset: 547 rows, 10 columns, no null values
print(illinois_emotion.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 10 columns):
# Week of:                 547 non-null object
# Total Number of Posts    547 non-null int64
# Fear                     547 non-null int64
# Anger                    547 non-null int64
# Joy                      547 non-null int64
# Sadness                  547 non-null int64
# Surprise                 547 non-null int64
# Neutral                  547 non-null int64
# Disgust                  547 non-null int64
# No Emotion Attached      547 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 42.9+ KB
# None

# %%
illinois_emotion_int = illinois_emotion.drop('Week of: ', axis=1)

# %%
for col in illinois_emotion_int.columns:
    sns.distplot(illinois_emotion[col])
    plt.show()

# %%
# Correlation matrix
cor = illinois_emotion_int.corr()
cor
# Out:
#                        Total Number of Posts      Fear     Anger       Joy  \
# Total Number of Posts               1.000000  0.608467  0.664109  0.824338
# Fear                                0.608467  1.000000  0.193532  0.577569
# Anger                               0.664109  0.193532  1.000000  0.398483
# Joy                                 0.824338  0.577569  0.398483  1.000000
# Sadness                             0.854312  0.556608  0.602257  0.821155
# Surprise                            0.572319  0.447572  0.262267  0.701390
# Neutral                             0.603697  0.438880  0.149079  0.510480
# Disgust                             0.952750  0.501415  0.631362  0.696044
# No Emotion Attached                 0.066188  0.051551 -0.060849  0.022300
#
#                         Sadness  Surprise   Neutral   Disgust  \
# Total Number of Posts  0.854312  0.572319  0.603697  0.952750
# Fear                   0.556608  0.447572  0.438880  0.501415
# ...

# %%
# Figure size
plt.figure(figsize=(12,8))

# Heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()
